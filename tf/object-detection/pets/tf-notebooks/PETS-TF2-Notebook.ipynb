# %% [markdown]
# ### NECESSARY IMPORTS

# %%
import matplotlib
import matplotlib.pyplot as plt

import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
import tarfile
import shutil
import six.moves.urllib as urllib
from shutil import copyfile
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
#from object_detection.utils import colab_utils
from object_detection.builders import model_builder

# %matplotlib inline

# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 2318, done.
# remote: Counting objects: 100% (2318/2318), done.
# remote: Compressing objects: 100% (2016/2016), done.
# remote: Total 2318 (delta 564), reused 928 (delta 278), pack-reused 0
# Receiving objects: 100% (2318/2318), 30.64 MiB | 37.85 MiB/s, done.
# Resolving deltas: 100% (564/564), done.
# Checking out files: 100% (2165/2165), done.

# %%
cwd = os.getcwd()
dkube_dir_path=cwd

# %% [markdown]
# ### WORKSPACE

# %%
# Directory for pets
directory = "pets_detection"
  
# Parent Directory path 
parent_dir = dkube_dir_path
  
# Path 
path = os.path.join(parent_dir, directory) 

os.mkdir(path) 
print("Directory '%s' created" %directory)
# Out:
# Directory 'pets_detection' created

# %%
base_path = dkube_dir_path+"/pets_detection"
annotations_path="/annotations"
data_path="data"
images_path="/images"
models_path="/models"

data_dir_path = os.path.join(base_path,data_path) 

os.mkdir(data_dir_path) 
print("Directory '%s' created" %data_path)

##### Creating the test-images and test-annotations folder ######
os.mkdir(base_path+images_path)
os.mkdir(base_path+models_path)
os.mkdir(base_path+annotations_path)
os.mkdir(base_path+images_path+"/test") 
os.mkdir(base_path+images_path+"/train")
# Out:
# Directory 'data' created

# %% [markdown]
# ### DOWNLOADING THE DATASET

# %%
def download(data_dir):
    opener = urllib.request.URLopener()
    opener.retrieve("https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz",data_dir +"/annotations.tar.gz")
    opener.retrieve("https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz", data_dir + "/images.tar.gz")
    print("Downloaded and saved the dataset. Location: ",data_dir)

# %%
download(data_dir_path)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: URLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   """Entry point for launching an IPython kernel.
# Downloaded and saved the dataset. Location:  /home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/data

# %% [markdown]
# ### EXTRACTING THE DATASET

# %%
def extract(data_dir_path):
    print(data_dir_path)
    files = [os.path.join(data_dir_path, f) for f in os.listdir(data_dir_path) if f.endswith('tar.gz')]
    print(files)
    for filename in files:
        print(filename)
        tar = tarfile.open(filename)
        tar.extractall(data_dir_path)
        tar.close()
    print("Extracted objects and stored. Location: ",data_dir_path)

# %%
extract(data_dir_path)
# Out:
# /home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/data
# ['/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/data/annotations.tar.gz', '/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/data/images.tar.gz']
# /home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/data/annotations.tar.gz
# /home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/data/images.tar.gz
# Extracted objects and stored. Location:  /home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/data

# %% [markdown]
# ### DATA CLEANING

# %%
source=base_path+"/data/annotations/xmls/"
destination=base_path+"/data/images/"
for file in os.listdir(source):
    shutil.copy(source+file,destination)

# %%
xml_path=base_path+"/data/annotations/xmls/"
image_path=base_path+"/data/images/"
xml_list=[]
images_list=[]
for xml_file in os.listdir(xml_path):
    if xml_file.endswith('.xml'):
        xml_list.append(xml_file.strip('.xml'))

for image_file in os.listdir(image_path):
    if image_file.endswith('jpg'):
        images_list.append(image_file.strip('.jpg'))

# %%
len(xml_list)
# Out:
# 3686

# %%
len(images_list)
# Out:
# 7390

# %%
final_dataset_list=list(set(xml_list)& set(images_list))

# %%
len(final_dataset_list)
# Out:
# 2986

# %%
os.mkdir(base_path+"/data/final_images")

# %%
source=base_path+"/data/images/"
destination=base_path+"/data/final_images/"
for file in os.listdir(source):
    file=file.strip('.jpg')
    if file in final_dataset_list:
        shutil.copy(source+file+'.jpg',destination)

# %%
! ls pets_detection/data/final_images/ | wc -l
# Out:
# 2986

# %%
source=base_path+"/data/annotations/xmls/"
destination=base_path+"/data/final_images/"
for file in os.listdir(source):
    file=file.strip('.xml')
    if file in final_dataset_list:
        shutil.copy(source+file+'.xml',destination)

# %%
# !ls pets_detection/data/final_images/ | wc -l
# Out:
# 5972

# %% [markdown]
# ### PARTITION THE DATASET INTO TRAIN AND TEST

# %%
import os
import re
from shutil import copyfile
import argparse
import math
import random


def iterate_dir(source, dest, ratio, copy_xml):
    source = source.replace('\\', '/')
    dest = dest.replace('\\', '/')
    train_dir = os.path.join(dest, 'train')
    test_dir = os.path.join(dest, 'test')

    if not os.path.exists(train_dir):
        os.makedirs(train_dir)
    if not os.path.exists(test_dir):
        os.makedirs(test_dir)

    images = [f for f in os.listdir(source)
              if re.search(r'([a-zA-Z0-9\s_\\.\-\(\):])+(.jpg|.jpeg|.png)$', f)]

    num_images = len(images)
    num_test_images = math.ceil(ratio*num_images)

    for i in range(num_test_images):
        idx = random.randint(0, len(images)-1)
        filename = images[idx]
        copyfile(os.path.join(source, filename),
                 os.path.join(test_dir, filename))
        if copy_xml:
            xml_filename = os.path.splitext(filename)[0]+'.xml'
            copyfile(os.path.join(source, xml_filename),
                     os.path.join(test_dir,xml_filename))
        images.remove(images[idx])

    for filename in images:
        copyfile(os.path.join(source, filename),
                 os.path.join(train_dir, filename))
        if copy_xml:
            xml_filename = os.path.splitext(filename)[0]+'.xml'
            copyfile(os.path.join(source, xml_filename),
                     os.path.join(train_dir, xml_filename))

# %%
iterate_dir(base_path+'/data/final_images', base_path+'/images', 0.1,'store_true')

# %%
shutil.copy(dkube_dir_path+'/label_map.pbtxt',base_path+'/annotations')
# Out:
# '/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/annotations/label_map.pbtxt'

# %% [markdown]
# ### GENERATING TENSORFLOW RECORDS

# %%
# !python generate_tfrecord.py -x pets_detection/images/train -l pets_detection/annotations/label_map.pbtxt -o pets_detection/annotations/train.record
# Out:
# Successfully created the TFRecord file: pets_detection/annotations/train.record

# %%
# !python generate_tfrecord.py -x pets_detection/images/test -l pets_detection/annotations/label_map.pbtxt -o pets_detection/annotations/test.record
# Out:
# Successfully created the TFRecord file: pets_detection/annotations/test.record

# %% [markdown]
# ### DOWNLOAD THE PRETRAINED MODEL

# %%
opener = urllib.request.URLopener()
opener.retrieve("http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz",base_path +"/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz")
# Out:
# ('/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz',
#  <http.client.HTTPMessage at 0x7fe9da4b9128>)

# %%
tar = tarfile.open(base_path+'/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz')
tar.extractall(base_path)
tar.close()

# %%
os.mkdir(base_path+"/my_ssd_resnet50_v1_fpn")

# %%
shutil.copy(dkube_dir_path+'/pipeline.config',base_path+'/my_ssd_resnet50_v1_fpn/')
# Out:
# '/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/my_ssd_resnet50_v1_fpn/pipeline.config'

# %% [markdown]
# ### TRAINING STARTS HERE

# %%
# !python models/research/object_detection/model_main_tf2.py --model_dir=pets_detection/my_ssd_resnet50_v1_fpn --pipeline_config_path=pets_detection/my_ssd_resnet50_v1_fpn/pipeline.config
# Out:
# INFO:tensorflow:Initializing local devices since in-graph multi-worker training with `MirroredStrategy` is not supported in eager mode. TF_CONFIG will be ignored when when initializing `MirroredStrategy`.
# I1201 11:05:03.821477 140020175431488 mirrored_strategy.py:302] Initializing local devices since in-graph multi-worker training with `MirroredStrategy` is not supported in eager mode. TF_CONFIG will be ignored when when initializing `MirroredStrategy`.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1201 11:05:05.014353 140020175431488 mirrored_strategy.py:341] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I1201 11:05:05.023457 140020175431488 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1201 11:05:05.023717 140020175431488 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Reading unweighted datasets: ['/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/annotations/train.record']
# I1201 11:05:05.237770 140020175431488 dataset_builder.py:148] Reading unweighted datasets: ['/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/annotations/train.record']
# I1201 11:05:05.239156 140020175431488 dataset_builder.py:77] Reading record datasets for input file: ['/home/ocdkube/workspace/PETS-TF2/tf/object-detection/pets/tf-notebooks/pets_detection/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1201 11:05:05.239326 140020175431488 dataset_builder.py:78] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1201 11:05:05.239410 140020175431488 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:103: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W1201 11:05:05.243643 140020175431488 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:103: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:222: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1201 11:05:05.282286 140020175431488 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:222: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W
, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1aa2828>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I1201 13:29:58.708245 140394587744064 def_function.py:1038] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1aa24a8>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1aa2518>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1aa2828>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1ae1710>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1ae16a0>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1ae1390>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I1201 13:29:58.708713 140394587744064 def_function.py:1038] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1ae1710>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1ae16a0>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1ae1390>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a68ac8>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a68b38>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a68e48>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I1201 13:29:58.709342 140394587744064 def_function.py:1038] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a68ac8>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a68b38>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a68e48>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a5c0b8>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a5c128>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a5c438>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I1201 13:29:58.709683 140394587744064 def_function.py:1038] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a5c0b8>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a5c128>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7facf1a5c438>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Assets written to: pets_detection/models/exported-model/saved_model/assets
# I1201 13:30:01.483230 140394587744064 builder_impl.py:775] Assets written to: pets_detection/models/exported-model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to pets_detection/models/exported-model/pipeline.config
# I1201 13:30:02.799870 140394587744064 config_util.py:254] Writing pipeline config file to pets_detection/models/exported-model/pipeline.config

# %% [markdown]
# ### INFERENCE

# %%
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL =base_path+"/models/exported-model"+"/saved_model"

print('Loading model...', end='')
start_time = time.time()

# Load saved model and build the detection function
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# Loading model...Done! Took 14.863430261611938 seconds

# %%
category_index = label_map_util.create_category_index_from_labelmap(base_path+"/annotations/label_map.pbtxt",use_display_name=True)

# %%
### inference-images folder will contain images for which we want inference

# %%
inference_image_folder=dkube_dir_path+"/inference-images/"

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
      path: the file path to the image

    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))


for image_path in os.listdir(inference_image_folder):

    print('Running inference for {}... '.format(image_path), end='')

    image_np = load_image_into_numpy_array(inference_image_folder+image_path)

    # Things to try:
    # Flip horizontally
    # image_np = np.fliplr(image_np).copy()

    # Convert image to grayscale
    # image_np = np.tile(
    #     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

    # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
    input_tensor = tf.convert_to_tensor(image_np)
    # The model expects a batch of images, so add an axis with `tf.newaxis`.
    input_tensor = input_tensor[tf.newaxis, ...]

    # input_tensor = np.expand_dims(image_np, 0)
    detections = detect_fn(input_tensor)

    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimension.
    # We're only interested in the first num_detections.
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                   for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)
    #print(detections['detection_boxes'])
    #print(detections['detection_scores'])

    image_np_with_detections = image_np.copy()
    #print(image_np_with_detections)

    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'],
          detections['detection_classes'],
          detections['detection_scores'],
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=200,
          min_score_thresh=.26,
          agnostic_mode=False)

    plt.figure()
    plt.imshow(image_np_with_detections)
    print('Done')
plt.show()

# sphinx_gallery_thumbnail_number = 2
# Out:
# Running inference for image1.jpg... Done
